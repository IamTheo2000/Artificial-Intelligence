# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
from pyswip import Prolog
 
# Διάβασμα του αρχείου 'movie_metadata.csv' 
path = r"C:\Users\OWNER\Desktop\AI Σειρα 2\2ο Θέμα"
data = pd.read_csv(path + "\movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
import pandas as pd
from pyswip import Prolog

def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
 
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))

#ids epeidh oi titloi Out of the blue, Batman, The host yparxoun parapanw apo 2 fores
  ident = getattr(row, 'id')
  literals.append("identification('"+ movie_title +"','"+ str(ident) +"')")

#plot keywords
  for plotkeys in getattr(row, 'plot_keywords').split("|"):
    plot = clean_text(plotkeys)
    literals.append("plot('"+ str(ident) +"','"+ plot +"')")

#language
  lang = getattr(row, 'language')
  literals.append("language('"+ str(ident) +"','"+ lang +"')")

#genre
  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ str(ident) +"','"+ genre +"')")

#popularity
  pop = getattr(row, 'popularity')
  literals.append("popularity('"+ str(ident) +"','"+ str(pop) +"')")  # den evala int alla string

#production company
  comp = getattr(row, 'production_companies')
  if comp != '[]':
    arr = comp.replace('[','').replace('}]','').split('}, ')
    for s in arr:
      s = clean_text(s).replace('{name: ','').replace(', id: ',',').split(',')[0]
      literals.append("production_company('"+ str(ident) +"','"+ s +"')")
  else:
    literals.append("production_company('"+ str(ident) +"','""')") #indie

#production country
  countries = getattr(row, 'production_countries')
  if countries != '[]':
    countries = countries.replace('[','').replace('}]','').split('}, ')
    for s in countries:
      s = clean_text(s).replace('name: ','').replace(', id: ',',').split(',')[1]
      literals.append("production_country('"+ str(ident) +"','"+ s +"')")
  else:
    literals.append("production_country('"+ str(ident) +"','""')")

#release date
  date = getattr(row, 'release_date')
  literals.append("release_date('"+ str(ident) +"','"+ date +"')")

#duration
  dur = getattr(row, 'duration')
  literals.append("duration('"+ str(ident) +"','"+ str(dur) +"')")

#languages spoken
  slang = getattr(row, 'spoken_languages')
  if slang != '[]':
    slang = slang.replace('[','').replace('}]','').split('}, ')
    for s in slang:
      s = clean_text(s).replace('name: ','').replace(', id: ',',').split(',')[1]
      literals.append("spoken_languages('"+ str(ident) +"','"+ s +"')")
  else:
    literals.append("spoken_languages('"+ str(ident) +"','""')")

#reviews
  avg = getattr(row, 'vote_average')
  literals.append("vote_average('"+ str(ident) +"','"+ str(avg) +"')")

#year
  year = getattr(row, 'title_year')
  literals.append("title_year('"+ str(ident) +"','"+ str(year) +"')")

#director
  director = getattr(row, 'director_name')
  literals.append("director('"+ str(ident) +"','"+ clean_text(director) +"')")

#actor1
  actor1 = getattr(row, 'actor_1_name')
  literals.append("actor_1('"+ str(ident) +"','"+ clean_text(actor1) +"')")

#actor2
  actor2 = getattr(row, 'actor_2_name')
  literals.append("actor_2('"+ str(ident) +"','"+ clean_text(actor2) +"')")

#actor3
  actor3 = getattr(row, 'actor_3_name')
  literals.append("actor_3('"+ str(ident) +"','"+ clean_text(actor3) +"')")
    
#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()
for literal in literals:
  prolog.assertz(literal)
  print (literal +'.')
# Out:
# ---------------------------------------------------------------------------
# PrologError                               Traceback (most recent call last)
# <ipython-input-4-6bd1975071df> in <module>
#     105 literals.sort()
#     106 for literal in literals:
# --> 107   prolog.assertz(literal)
#     108   print (literal +'.')
#
# ~\anaconda3\lib\site-packages\pyswip\prolog.py in assertz(cls, assertion, catcherrors)
#     138     @classmethod
#     139     def assertz(cls, assertion, catcherrors=False):
# --> 140         next(cls.query(assertion.join(["assertz((", "))."]), catcherrors=catcherrors))
#     141
#     142     @classmethod
#
# ~\anaconda3\lib\site-packages\pyswip\prolog.py in __call__(self, query, maxresult, catcherrors, normalize)
#     124                     term = getTerm(PL_exception(swipl_qid))
#     125
# --> 126                     raise PrologError("".join(["Caused by: '", query, "'. ",
#     127                                                "Returned: '", str(term), "'."]))
#     128
#
# PrologError: Caused by: 'assertz((actor_1('100','Dexter Fletcher'))).'. Returned: 'error(permission_error(modify, static_procedure, /(actor_1, 2)), context(:(system, /(assertz, 1)), _2484))'.

# %%
comp = "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]"
arr = comp.replace('[','').replace('}]','').split('}, ')
for s in arr:
    s = clean_text(s).replace('name: ','').replace(', id: ',',').split(',')[1]
    print(s)
# Out:
#  United Kingdom
#  United States of America

# %%
wtf = "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]"
wtf = wtf.replace('[','').replace('}]','').split('}, ')
for s in wtf:
  s = clean_text(s).replace('name: ','').replace(', id: ',',').split(',')[1]
  print(s)
# Out:
#  United Kingdom
#  United States of America

# %%
import pandas as pd
from pyswip import Prolog

prolog = Prolog()
changeme = "/Users/OWNER/Desktop/testdrive.pl"
prolog.consult(changeme)

# %%
q = prolog.query("vs_genre('Avatar',L)")
a = next(q)
a = {variable: [str(elem) for elem in a[variable]] for variable in a}
q.close()
print(a['L'])
# Out:
# ['2012', '47 Ronin', '9', 'A Sound of Thunder', 'AVP: Alien vs. Predator', 'After Earth', 'Aliens in the Attic', 'Aliens vs Predator: Requiem', 'Anacondas: The Hunt for the Blood Orchid', 'Ant-Man', 'Armageddon', 'Avengers: Age of Ultron', 'Babylon A.D.', 'Batman v Superman: Dawn of Justice', 'Battleship', 'Beastmaster 2: Through the Portal of Time', 'Big Trouble in Little China', 'Bill & Teds Bogus Journey', 'Blade: Trinity', 'BloodRayne', 'Brave', 'Captain America: Civil War', 'Captain America: The First Avenger', 'Captain America: The Winter Soldier', 'Cirque du Freak: The Vampires Assistant', 'Clash of the Titans', 'Conan the Barbarian', 'Conan the Destroyer', 'Congo', 'Damnation Alley', 'Daybreakers', 'Deep Rising', 'Delgo', 'Divergent', 'Dragon Wars: D-War', 'Dragonball Evolution', 'Dune', 'Dungeons & Dragons: Wrath of the Dragon God', 'E.T. the Extra-Terrestrial', 'Enders Game', 'Eragon', 'Escape from L.A.', 'Fantastic 4: Rise of the Silver Surfer', 'Fantastic Four', 'Final Fantasy: The Spirits Within', 'Firefox', 'G-Force', 'G.I. Joe: Retaliation', 'G.I. Joe: The Rise of Cobra', 'Godzilla 2000', 'Green Lantern', 'Guardians of the Galaxy', 'Hellboy II: The Golden Army', 'Hellboy', 'Highlander', 'Highlander: Endgame', 'Highlander: The Final Dimension', 'How to Train Your Dragon 2', 'I Am Number Four', 'In the Name of the King III', 'In the Name of the King: A Dungeon Siege Tale', 'Inception', 'Independence Day', 'Independence Day: Resurgence', 'Iron Man 2', 'Iron Man 3', 'Iron Man', 'Jimmy Neutron: Boy Genius', 'John Carter', 'Jonah: A VeggieTales Movie', 'Journey 2: The Mysterious Island', 'Journey to Saturn', 'Journey to the Center of the Earth', 'Jumper', 'Jupiter Ascending', 'Jurassic Park III', 'Jurassic World', 'Knowing', 'Krull', 'Lara Croft Tomb Raider: The Cradle of Life', 'Lara Croft: Tomb Raider', 'Last Action Hero', 'Logans Run', 'Mad Max 2: The Road Warrior', 'Mad Max Beyond Thunderdome', 'Mad Max', 'Mad Max: Fury Road', 'Maleficent', 'Man of Steel', 'Megaforce', 'Men in Black II', 'Men in Black', 'Mighty Joe Young', 'Mirror Mirror', 'Monkeybone', 'Moonraker', 'Mortal Kombat: Annihilation', 'My Super Ex-Girlfriend', 'Mystery Men', 'Night at the Museum', 'Night at the Museum: Battle of the Smithsonian', 'Oblivion', 'Pacific Rim', 'Paycheck', 'Pirates of the Caribbean: At Worlds End', 'Pirates of the Caribbean: Dead Mans Chest', 'Pirates of the Caribbean: On Stranger Tides', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Planet of the Apes', 'PokÃ©mon: Spell of the Unknown', 'Predator', 'Predators', 'Priest', 'Prince of Persia: The Sands of Time', 'Puss in Boots', 'Race to Witch Mountain', 'Red Sonja', 'Reign of Fire', 'Resident Evil: Afterlife', 'Return of the Jedi', 'RoboCop 3', 'Serenity', 'Sheena', 'Shin Godzilla', 'Six-String Samurai', 'Sky Captain and the World of Tomorrow', 'Small Soldiers', 'Southland Tales', 'Spawn', 'Spider-Man 2', 'Spider-Man 3', 'Spy Kids 3-D: Game Over', 'Star Trek Beyond', 'Star Trek II: The Wrath of Khan', 'Star Trek III: The Search for Spock', 'Star Trek Into Darkness', 'Star Trek V: The Final Frontier', 'Star Trek VI: The Undiscovered Country', 'Star Trek', 'Star Trek: First Contact', 'Star Trek: Generations', 'Star Trek: Insurrection', 'Star Trek: Nemesis', 'Star Wars', 'Star Wars: Clone Wars: Volume 1', 'Star Wars: Episode I - The Phantom Menace', 'Star Wars: Episode II - Attack of the Clones', 'Star Wars: Episode III - Revenge of the Sith', 'Starship Troopers', 'Steel', 'Street Fighter: The Legend of Chun-Li', 'Suicide Squad', 'Superman II', 'Superman III', 'Superman IV: The Quest for Peace', 'Superman Returns', 'Superman', 'TRON: Legacy', 'Tank Girl', 'Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'Teenage Mutant Ninja Turtles III', 'Teenage Mutant Ninja Turtles', 'Teenage Mutant Ninja Turtles: Out of the Shadows', 'Terminator Genisys', 'The 13th Warrior', 'The Abyss', 'The Amazing Spider-Man 2', 'The Amazing Spider-Man', 'The Avengers', 'The Black  ...

# %%
def ps_recommender(movie):
    q1 = prolog.query("vs_genre('" + movie +"',L)")
    vsg = next(q1)
    vsg = {variable: [str(elem) for elem in vsg[variable]] for variable in vsg}
    q1.close()
    
    q2 = prolog.query("s_char('" + movie +"',L)")
    sa = next(q2)
    sa = {variable: [str(elem) for elem in sa[variable]] for variable in sa}    
    q2.close()
    
    q3 = prolog.query("es_plot('" + movie +"',L)")
    esp = next(q3)
    esp = {variable: [str(elem) for elem in esp[variable]] for variable in esp}    
    q3.close()
    
    L1 = vsg['L']
    L2 = sa['L']
    L3 = esp['L']
    
    vsg_sa = []
    recom = []
    
    for movie in L1:
        if movie in L2:
            vsg_sa.append(movie)
    for movie in vsg_sa:
        if movie in L3:
            recom.append(movie)
            L3.remove(movie)
            vsg_sa.remove(movie)
            
    answer = recom + vsg_sa + L3
     
    return answer

# %%
ps_recommender('Harry Potter and the Half-Blood Prince')
# Out:
# ['Harry Potter and the Chamber of Secrets',
#  'Harry Potter and the Order of the Phoenix',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Philosophers Stone',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Philosophers Stone']

# %%
L = [1,2,3]
L.append(4)
L.remove(2)
L
# Out:
# [1, 3, 4]

# %%
def es_recommender(movie):
    q1 = prolog.query("vs_genre('" + movie +"',L)")
    vsg = next(q1)
    vsg = {variable: [str(elem) for elem in vsg[variable]] for variable in vsg}
    q1.close()
    
    q2 = prolog.query("s_char('" + movie +"',L)")
    sa = next(q2)
    sa = {variable: [str(elem) for elem in sa[variable]] for variable in sa}    
    q2.close()
    
    q3 = prolog.query("vs_plot('" + movie +"',L)")
    vsp = next(q3)
    vsp = {variable: [str(elem) for elem in vsp[variable]] for variable in vsp}    
    q3.close()
    
    L1 = vsg['L']
    L2 = sa['L']
    L3 = vsp['L']
    
    vsg_sa = []
    recom = []
    
    for movie in L1:
        if movie not in L2 and movie in L3:
            vsg_sa.append(movie)
            L3.remove(movie)

            
    answer = vsg_sa + L3
     
    return answer

# %%
es_recommender('Harry Potter and the Half-Blood Prince')
# Out:
# ['Oz: The Great and Powerful',
#  'Spirited Away',
#  'Conan the Destroyer',
#  'Goosebumps',
#  'Hotel Transylvania 2',
#  'Hotel Transylvania',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Practical Magic',
#  'The Craft',
#  'The Huntsman: Winters War',
#  'The Sorcerers Apprentice',
#  'Warlock']

# %%
def vs_recommender(movie):
    q1 = prolog.query("vs_genre('" + movie +"',L)")
    vsg = next(q1)
    vsg = {variable: [str(elem) for elem in vsg[variable]] for variable in vsg}
    q1.close()

    q2 = prolog.query("vs_plot('" + movie +"',L)")
    vsp = next(q2)
    vsp = {variable: [str(elem) for elem in vsp[variable]] for variable in vsp}    
    q2.close()
    
    q3 = prolog.query("s_plot('" + movie +"',L)")
    sp = next(q3)
    sp = {variable: [str(elem) for elem in sp[variable]] for variable in sp}    
    q3.close()
    
    q4 = prolog.query("es_plot('" + movie +"',L)")
    esp = next(q4)
    esp = {variable: [str(elem) for elem in esp[variable]] for variable in esp}    
    q4.close()
    
    q5 = prolog.query("s_genre('" + movie +"',L)")
    sg = next(q5)
    sg = {variable: [str(elem) for elem in sg[variable]] for variable in sg}
    q5.close()
    
    L1 = vsg['L']
    L2 = vsp['L']
    L3 = sp['L']
    L4 = esp['L']
    L5 = sg['L']
    
    helper = []
    recom = []
    
    for movie in L1:
        if movie in L3:
            helper.append(movie)
            L3.remove(movie)
            L1.remove(movie)
    for movei in L1:
        if movei in L2 or movei in L4:
            L1.remove(movei)
            
    for movie in helper:
        if movie in sg:
            helper.remove(movie)
            
    answer = helper + L1
     
    return answer

# %%
vs_recommender('Harry Potter and the Half-Blood Prince')
# Out:
# ['A Simple Wish',
#  'Asterix at the Olympic Games',
#  'Last Action Hero',
#  'Pan',
#  'Shrek 2',
#  'Shrek',
#  'Stardust',
#  'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#  'The NeverEnding Story',
#  'The Smurfs',
#  'The Thief and the Cobbler',
#  'The Wizard of Oz',
#  'Time Bandits',
#  'A Monster in Paris',
#  'Aladdin',
#  'Alice in Wonderland',
#  'Aliens in the Attic',
#  'Arthur and the Invisibles',
#  'Babe: Pig in the City',
#  'Bill & Teds Bogus Journey',
#  'Brave',
#  'Charlie and the Chocolate Factory',
#  'City of Ember',
#  'Delgo',
#  'Dragon Nest: Warriors Dawn',
#  'E.T. the Extra-Terrestrial',
#  'Epic',
#  'Eragon',
#  'G-Force',
#  'Harry Potter and the Goblet of Fire',
#  'Harry Potter and the Philosophers Stone',
#  'Herbie Fully Loaded',
#  'Hook',
#  'How to Train Your Dragon 2',
#  'How to Train Your Dragon',
#  'Inkheart',
#  'Jimmy Neutron: Boy Genius',
#  'Jonah: A VeggieTales Movie',
#  'Legend of the Guardians: The Owls of GaHoole',
#  'Maleficent',
#  'Mighty Joe Young',
#  'Mirror Mirror',
#  'Night at the Museum',
#  'Night at the Museum: Battle of the Smithsonian',
#  'Night at the Museum: Secret of the Tomb',
#  'Nims Island',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'Percy Jackson: Sea of Monsters',
#  'Petes Dragon',
#  'PokÃ©mon: Spell of the Unknown',
#  'Puss in Boots',
#  'Race to Witch Mountain',
#  'Return to Never Land',
#  'Return to Oz',
#  'Shrek Forever After',
#  'Shrek the Third',
#  'Son of the Mask',
#  'Super Mario Bros.',
#  'Teenage Mutant Ninja Turtles III',
#  'The Adventurer: The Curse of the Midas Box',
#  'The Ant Bully',
#  'The BFG',
#  'The Book of Life',
#  'The Borrowers',
#  'The Brave Little Toaster',
#  'The Chronicles of Narnia: Prince Caspian',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'The Croods',
#  'The Emperors New Groove',
#  'The Indian in the Cupboard',
#  'The Iron Giant',
#  'The Jungle Book',
#  'The Last Airbender',
#  'The Lego Movie',
#  'The Polar Express',
#  'The Princess Bride',
#  'The Spiderwick Chronicles',
#  'The Wiz',
#  'Thunder and the House of Magic',
#  'Thunderbirds',
#  'Treasure Planet',
#  'Zathura: A Space Adventure']

# %%
def s_recommender(movie):
    q1 = prolog.query("s_genre('" + movie +"',L)")
    sg = next(q1)
    sg = {variable: [str(elem) for elem in sg[variable]] for variable in sg}
    q1.close()

    q2 = prolog.query("vs_plot('" + movie +"',L)")
    vsp = next(q2)
    vsp = {variable: [str(elem) for elem in vsp[variable]] for variable in vsp}    
    q2.close()
    
    q3 = prolog.query("s_plot('" + movie +"',L)")
    sp = next(q3)
    sp = {variable: [str(elem) for elem in sp[variable]] for variable in sp}    
    q3.close()
    
    q4 = prolog.query("es_plot('" + movie +"',L)")
    esp = next(q4)
    esp = {variable: [str(elem) for elem in esp[variable]] for variable in esp} 
    q4.close()
    
    q5 = prolog.query("vs_genre('" + movie +"',L)")
    vsg = next(q5)
    vsg = {variable: [str(elem) for elem in vsg[variable]] for variable in vsg}
    q5.close()    
    
    L1 = sg['L']
    L2 = vsp['L']
    L3 = sp['L']
    L4 = esp['L']
    L5 = vsg['L']
    
    helper = []
    recom = []
    
    for movie in L3:
        if movie in L5:
            L3.remove(movie)
            
    for movie in L1:
        if movie in L2  or movie in L4:
            L1.remove(movie)
    
    for movie in L1:
        if movie in L3:
            L1.remove(movie)
            L3.remove(movie)
            helper.append(movie)   
            
    answer = helper + L3 + L1
     
    return answer

# %%
s_recommender('Harry Potter and the Half-Blood Prince')
# Out:
# ['Big Fish',
#  'Big Trouble in Little China',
#  'Bogus',
#  'Cinderella',
#  'Ella Enchanted',
#  'Happily NEver After',
#  'Hocus Pocus',
#  'Howls Moving Castle',
#  'Mary Poppins',
#  'Nanny McPhee',
#  'Pirates of the Caribbean: Dead Mans Chest',
#  'Seventh Son',
#  'Snow White and the Huntsman',
#  'Teen Wolf Too',
#  'The 13th Warrior',
#  'The Covenant',
#  'The Haunted Mansion',
#  'The Last Witch Hunter',
#  'The Mortal Instruments: City of Bones',
#  'The Santa Clause 2',
#  'The Twilight Saga: Eclipse',
#  'Underworld: Rise of the Lycans',
#  'Warcraft',
#  'A Very Long Engagement',
#  'An American Haunting',
#  'Army of Darkness',
#  'Beautiful Creatures',
#  'Being John Malkovich',
#  'Blood and Chocolate',
#  'Book of Shadows: Blair Witch 2',
#  'Charlie Bartlett',
#  'Crazy/Beautiful',
#  'Cursed',
#  'Dark Shadows',
#  'Darkness Falls',
#  'Deceptive Practice: The Mysteries and Mentors of Ricky Jay',
#  'DragonHeart',
#  'Dragonslayer',
#  'Dune',
#  'Dylan Dog: Dead of Night',
#  'Four Rooms',
#  'Fur: An Imaginary Portrait of Diane Arbus',
#  'Hansel & Gretel: Witch Hunters',
#  'Hansel and Gretel Get Baked',
#  'Hoodwinked Too! Hood VS. Evil',
#  'Into the Woods',
#  'Kung Fu Hustle',
#  'Meet Joe Black',
#  'Night Watch',
#  'Not Another Teen Movie',
#  'Now You See Me 2',
#  'Now You See Me',
#  'Paranormal Activity 3',
#  'Pinocchio',
#  'Red Riding Hood',
#  'Scoop',
#  'Shrek',
#  'Sleepover',
#  'Snow White and the Seven Dwarfs',
#  'Summer Storm',
#  'Tangled',
#  'The Addams Family',
#  'The Blair Witch Project',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'The Crying Game',
#  'The Howling',
#  'The Illusionist',
#  'The Immigrant',
#  'The Incredible Burt Wonderstone',
#  'The Lords of Salem',
#  'The Medallion',
#  'The Prestige',
#  'The Sisterhood of Night',
#  'The Thief and the Cobbler',
#  'The Twilight Saga: New Moon',
#  'The Witch',
#  'The Wolfman',
#  'Thumbsucker',
#  'Time Bandits',
#  'Underworld',
#  'Underworld: Awakening',
#  'Underworld: Evolution',
#  'Wolf',
#  'Wolves',
#  '3 Ninjas Kick Back',
#  '47 Ronin',
#  'A Bugs Life',
#  'Against the Wild',
#  'Alpha and Omega: The Legend of the Saw Tooth Cave',
#  'Alvin and the Chipmunks',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Alvin and the Chipmunks: The Road Chip',
#  'Alvin and the Chipmunks: The Squeakquel',
#  'Antz',
#  'Aquamarine',
#  'Are We There Yet?',
#  'Atlantis: The Lost Empire',
#  'Avatar',
#  'Babe',
#  'Babys Day Out',
#  'Back to the Future Part II',
#  'Back to the Future Part III',
#  'Back to the Future',
#  'Batman v Superman: Dawn of Justice',
#  'Batman',
#  'Beastmaster 2: Through the Portal of Time',
#  'Bedtime Stories',
#  'Bee Movie',
#  'Benji',
#  'Beverly Hills Chihuahua',
#  'Big Hero 6',
#  'Big',
#  'Black Knight',
#  'Blade: Trinity',
#  'BloodRayne',
#  'Bolt',
#  'Bridge to Terabithia',
#  'CJ7',
#  'Cars 2',
#  'Cars',
#  'Casper',
#  'Catch That Kid',
#  'Charlottes Web',
#  'Cirque du Freak: The Vampires Assistant',
#  'Cirque du Soleil: Worlds Away',
#  'Clash of the Titans',
#  'Clockstoppers',
#  'Conan the Barbarian',
#  'Crossroads',
#  'Curious George',
#  'Digimon: The Movie',
#  'Doctor Dolittle',
#  'Dogma',
#  'Dr. Dolittle 2',
#  'Dragonball Evolution',
#  'Duma',
#  'Dungeons & Dragons: Wrath of the Dragon God',
#  'Earth to Echo',
#  'Eight Below',
#  'Elf',
#  'Enchanted',
#  'Escape from Planet Earth',
#  'Evan Almighty',
#  'Fantastic 4: Rise of the Silver Surfer',
#  'Fantastic Mr. Fox',
#  'Final Fantasy: The Spirits Within',
#  'Flipper',
#  'Flushed Away',
#  'Forbidden Kingdom',
#  'Frozen',
#  'George of the Jungle',
#  'Hellboy II: The Golden Army',
#  'Highlander',
#  'Holes',
#  'Home Alone 2: Lost in New York',
#  'Home',
#  'How the Grinch Stole Christmas',
#  'Hugo',
#  'Ice Age',
#  'Ice Age: Continental Drift',
#  'Ice Age: Dawn of the Dinosaurs',
#  'Ice Age: The Meltdown',
#  'In the Name of the King III',
#  'Inspector Gadget',
#  'Its a Wonderful Life',
#  'Jack the Giant Slayer',
#  'Journey to the Center of the Earth',
#  'Jumper',
#  'Jungle Shuffle',
#  'Jupiter Ascending',
#  'Just My Luck',
#  'Khumba',
#  'Krull',
#  'Kung Fu Panda 3',
#  'Kung Fu Panda',
#  'Ladyhawke',
#  'Lara Croft Tomb Raider: The Cradle of Life',
#  'Lara Croft: Tomb Raider',
#  'Legend of a Rabbit',
#  'Like Mike',
#  'Lost in Space',
#  'Man of Steel',
#  'Mars Needs Moms',
#  'Max Keebles Big Move',
#  'Max',
#  'Meet Dave',
#  'Minions',
#  'Monkeybone',
#  'Monster House',
#  'Monsters vs Aliens',
#  'Monty Python and the Holy Grail',
#  'Mr. Peabody & Sherman',
#  'Mulan',
#  'Muppets Most Wanted',
#  'Muppets from Space',
#  'Mystery Men',
#  'Nancy Drew',
#  'Nicholas Nickleby',
#  'Open Season',
#  'Osmosis Jones',
#  'ParaNorman',
#  'Paul Blart: Mall Cop',
#  'Penguins of Madagascar',
#  'Pirates of the Caribbean: At Worlds End',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'Planet 51',
#  'Pocahontas',
#  'Prince of Persia: The Sands of Time',
#  'Princess Mononoke',
#  'Quest for Camelot',
#  'Rango',
#  'Ratatouille',
#  'Red Sonja',
#  'Reign of Fire',
#  'Rio 2',
#  'Rio',
#  'Rise of the Guardians',
#  'Rugrats in Paris: The Movie',
#  'Sausage Party',
#  'Savva. Heart of the Warrior',
#  'Scooby-Doo 2: Monsters Unleashed',
#  'Sheena',
#  'Shipwrecked',
#  'Sinbad: Legend of the Seven Seas',
#  'Sky High',
#  'Small Soldiers',
#  'Snow Dogs',
#  'Snow White and the Seven Dwarfs',
#  'Space Jam',
#  'Spawn',
#  'Spice World',
#  'Spider-Man 2',
#  'Spider-Man 3',
#  'Spirit: Stallion of the Cimarron',
#  'Spy Kids 2: The Island of Lost Dreams',
#  'Spy Kids 3-D: Game Over',
#  'Spy Kids',
#  'Star Wars: Clone Wars: Volume 1',
#  'Stormbreaker',
#  'Stuart Little 2',
#  'Stuart Little',
#  'Suicide Squad',
#  'Superman II',
#  'Superman III',
#  'Superman Returns',
#  'Superman',
#  'TMNT',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'Teenage Mutant Ninja Turtles',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'The Adventures of Huck Finn',
#  'The Adventures of Pinocchio',
#  'The Adventures of Rocky & Bullwinkle',
#  'The Adventures of Sharkboy and Lavagirl',
#  'The Amazing Spider-Man 2',
#  'The Amazing Spider-Man',
#  'The Barbarians',
#  'The Black Hole',
#  'The Black Stallion',
#  'The Blue Bird',
#  'The Blue Butterfly',
#  'The Boxtrolls',
#  'The Brothers Grimm',
#  'The Cat in the Hat',
#  'The Country Bears',
#  'The Crocodile Hunter: Collision Course',
#  'The Curse of the Were-Rabbit',
#  'The Fifth Element',
#  'The Flintstones',
#  'The Forbidden Kingdom',
#  'The Golden Compass',
#  'The Good Dinosaur',
#  'The Hitchhikers Guide to the Galaxy',
#  'The Hobbit: An Unexpected Journey',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Hobbit: The Desolation of Smaug',
#  'The Hole',
#  'The Hunger Games',
#  'The Imaginarium of Doctor Parnassus',
#  'The Incredibles',
#  'The Jungle Book 2',
#  'The Kid',
#  'The Land Before Time',
#  'The Last Legion',
#  'The Lion of Judah',
#  'The Little Prince',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Lord of the Rings: The Return of the King',
#  'The Lord of the Rings: The Two Towers',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'The Monkey King 2',
#  'The Mummy Returns',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'The Muppet Christmas Carol',
#  'The Muppet Movie',
#  'The Nut Job',
#  'The Nutcracker',
#  'The Nutcracker: The Untold Story',
#  'The Odd Life of Timothy Green',
#  'The Other Side of Heaven',
#  'The Pirates! In an Adventure with Scientists!',
#  'The Prince of Egypt',
#  'The Road to El Dorado',
#  'The Santa Clause',
#  'The Scorpion King',
#  'The Secret Life of Walter Mitty',
#  'The Secret of Kells',
#  'The Shadow',
#  'The Sisterhood of the Traveling Pants 2',
#  'The Smurfs 2',
#  'The SpongeBob Movie: Sponge Out of Water',
#  'The Tale of Despereaux',
#  'The True Story of Puss n Boots',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'The Twilight Saga: New Moon',
#  'The Warriors Way',
#  'The Wild Thornberrys Movie',
#  'The Wolverine',
#  'The Young and Prodigious T.S. Spivet',
#  'Thor',
#  'Thor: The Dark World',
#  'Titan A.E.',
#  'Tomorrowland',
#  'Troop Beverly Hills',
#  'Tuck Everlasting',
#  'Twilight',
#  'Two Brothers',
#  'Up',
#  'Valiant',
#  'VeggieTales: The Pirates Who Dont Do Anything',
#  'Walking With Dinosaurs',
#  'Warriors of Virtue',
#  'Where the Wild Things Are',
#  'White Fang',
#  'Willy Wonka & the Chocolate Factory',
#  'Wreck-It Ralph',
#  'X-Men: Days of Future Past',
#  'Yogi Bear',
#  'Young Sherlock Holmes',
#  'Zambezia',
#  'Zoom']

# %%
L1 = vs_recommender('Harry Potter and the Half-Blood Prince')
L2 = s_recommender('Harry Potter and the Half-Blood Prince')
for i in L1:
    if i in L2:
        print(i)
# Out:
# Shrek
# The Thief and the Cobbler
# Time Bandits
# The Chronicles of Narnia: The Voyage of the Dawn Treader

# %%
movie = 'Harry Potter and the Half-Blood Prince'
q1 = prolog.query("s_genre('" + movie +"',L)")
sg = next(q1)
sg = {variable: [str(elem) for elem in sg[variable]] for variable in sg}
q1.close()

q2 = prolog.query("vs_genre('" + movie +"',L)")
vsg = next(q2)
vsg = {variable: [str(elem) for elem in vsg[variable]] for variable in vsg}
q2.close()

L = 'Shrek'
L in sg
# Out:
# False
